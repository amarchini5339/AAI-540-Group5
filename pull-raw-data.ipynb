# %% [markdown]
# # Download Raw Data from S3
#
# This notebook downloads the three network traffic datasets (CIC-IDS2017, TON_IOT, UNSW_NB15) from the S3 bucket.

# %%
import boto3
import os
from botocore import UNSIGNED
from botocore.config import Config

# %%
# Configure S3 client
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))
bucket_name = 'aai-540-final-project-group-5'

# %%
response = s3.list_objects_v2(Bucket=bucket_name)

# Create local base data directory
base_data_dir = '/home/sagemaker-user/data'
os.makedirs(base_data_dir, exist_ok=True)

folders_to_download = ['raw/CIC-IDS2017/', 'raw/TON_IOT/', 'raw/UNSW_NB15/']

print("Downloading datasets from S3 folders...")

if 'Contents' in response:
    for obj in response['Contents']:
        file_key = obj['Key']
        
        # Skip directory markers (0 byte files)
        if obj['Size'] == 0:
            continue
        
        # Check if file is in one of the folders we want
        for s3_folder in folders_to_download:
            if file_key.startswith(s3_folder):
                # Remove 'raw/' prefix for local storage
                local_key = file_key.replace('raw/', '', 1)
                local_path = os.path.join(base_data_dir, local_key)
                
                # Create subdirectories if needed
                local_dir = os.path.dirname(local_path)
                os.makedirs(local_dir, exist_ok=True)
                
                size_mb = obj['Size'] / (1024 * 1024)
                print(f"Downloading: {file_key} ({size_mb:.2f} MB)")
                s3.download_file(bucket_name, file_key, local_path)
                print(f"  Saved to: {local_path}")
                print()
                break
    
    print("All datasets downloaded successfully!")
else:
    print("No files to download.")
# Out:
# Downloading datasets from S3 folders...
# Downloading: raw/CIC-IDS2017/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv (73.55 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv (73.34 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Friday-WorkingHours-Morning.pcap_ISCX.csv (55.62 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Friday-WorkingHours-Morning.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Monday-WorkingHours.pcap_ISCX.csv (168.73 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Monday-WorkingHours.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv (79.25 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv (49.61 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Tuesday-WorkingHours.pcap_ISCX.csv (128.82 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Tuesday-WorkingHours.pcap_ISCX.csv
#
# Downloading: raw/CIC-IDS2017/Wednesday-workingHours.pcap_ISCX.csv (214.74 MB)
#   Saved to: /home/sagemaker-user/data/CIC-IDS2017/Wednesday-workingHours.pcap_ISCX.csv
#
# Downloading: raw/TON_IOT/Network_dataset_1.csv (139.93 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_1.csv
#
# Downloading: raw/TON_IOT/Network_dataset_10.csv (139.75 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_10.csv
#
# Downloading: raw/TON_IOT/Network_dataset_11.csv (141.55 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_11.csv
#
# Downloading: raw/TON_IOT/Network_dataset_12.csv (146.51 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_12.csv
#
# Downloading: raw/TON_IOT/Network_dataset_13.csv (144.02 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_13.csv
#
# Downloading: raw/TON_IOT/Network_dataset_14.csv (146.23 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_14.csv
#
# Downloading: raw/TON_IOT/Network_dataset_15.csv (146.10 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_15.csv
#
# Downloading: raw/TON_IOT/Network_dataset_16.csv (145.93 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_16.csv
#
# Downloading: raw/TON_IOT/Network_dataset_17.csv (142.92 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_17.csv
#
# Downloading: raw/TON_IOT/Network_dataset_18.csv (143.82 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_18.csv
#
# Downloading: raw/TON_IOT/Network_dataset_19.csv (149.69 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_19.csv
#
# Downloading: raw/TON_IOT/Network_dataset_2.csv (138.76 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_2.csv
#
# Downloading: raw/TON_IOT/Network_dataset_20.csv (150.31 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_20.csv
#
# Downloading: raw/TON_IOT/Network_dataset_21.csv (151.33 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_21.csv
#
# Downloading: raw/TON_IOT/Network_dataset_22.csv (146.17 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_22.csv
#
# Downloading: raw/TON_IOT/Network_dataset_23.csv (49.31 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_23.csv
#
# Downloading: raw/TON_IOT/Network_dataset_3.csv (138.87 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_3.csv
#
# Downloading: raw/TON_IOT/Network_dataset_4.csv (138.49 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_4.csv
#
# Downloading: raw/TON_IOT/Network_dataset_5.csv (138.50 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_5.csv
#
# Downloading: raw/TON_IOT/Network_dataset_6.csv (158.13 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_6.csv
#
# Downloading: raw/TON_IOT/Network_dataset_7.csv (140.36 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_7.csv
#
# Downloading: raw/TON_IOT/Network_dataset_8.csv (139.85 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_8.csv
#
# Downloading: raw/TON_IOT/Network_dataset_9.csv (139.72 MB)
#   Saved to: /home/sagemaker-user/data/TON_IOT/Network_dataset_9.csv
#
# Downloading: raw/UNSW_NB15/UNSW-NB15_1.csv (161.15 MB)
#   Saved to: /home/sagemaker-user/data/UNSW_NB15/UNSW-NB15_1.csv
#
# Downloading: raw/UNSW_NB15/UNSW-NB15_2.csv (157.57 MB)
#   Saved to: /home/sagemaker-user/data/UNSW_NB15/UNSW-NB15_2.csv
#
# Downloading: raw/UNSW_NB15/UNSW-NB15_3.csv (147.43 MB)
#   Saved to: /home/sagemaker-user/data/UNSW_NB15/UNSW-NB15_3.csv
#
# Downloading: raw/UNSW_NB15/UNSW-NB15_4.csv (93.07 MB)
#   Saved to: /home/sagemaker-user/data/UNSW_NB15/UNSW-NB15_4.csv
#
# All datasets downloaded successfully!
